# %%
from IPython.display import display, HTML

# Create a simple HTML string
html_str = """
<table>
    <tr>
        <th>Header 1</th>
        <th>Header 2</th>
    </tr>
    <tr>
        <td>row 1, cell 1</td>
        <td>row 1, cell 2</td>
    </tr>
    <tr>
        <td>row 2, cell 1</td>
        <td>row 2, cell 2</td>
    </tr>
</table>
"""

# Use IPython's display function to show the HTML
display(HTML(html_str))
# Out:
# <table>
#     <tr>
#         <th>Header 1</th>
#         <th>Header 2</th>
#     </tr>
#     <tr>
#         <td>row 1, cell 1</td>
#         <td>row 1, cell 2</td>
#     </tr>
#     <tr>
#         <td>row 2, cell 1</td>
#         <td>row 2, cell 2</td>
#     </tr>
# </table>
